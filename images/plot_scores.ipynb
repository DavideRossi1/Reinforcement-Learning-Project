# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
# old states system,  no pacman
SARSA_noboost_noPM=             pd.read_csv('scores/no_pacman/SARSA/scores_SARSA_noboost_noPM.txt',sep=',',comment='#',header=None)
SARSA_boost_noPM=               pd.read_csv('scores/no_pacman/SARSA/scores_SARSA_boost_noPM.txt',sep=',',comment='#',header=None)
SARSA_hybrid_noPM=              pd.read_csv('scores/no_pacman/SARSA/scores_SARSA_hybrid_noPM.txt',sep=',',comment='#',header=None)
SARSA_hybrid_noPM_bigenv=       pd.read_csv('scores/no_pacman/SARSA/scores_SARSA_hybrid_noPM_bigenv.txt',sep=',',comment='#',header=None)
SARSA_hybrid_noPM_diff4=        pd.read_csv('scores/no_pacman/SARSA/scores_SARSA_hybrid_noPM_diff4.txt',sep=',',comment='#',header=None)
SARSA_hybrid_noPM_diff6=        pd.read_csv('scores/no_pacman/SARSA/scores_SARSA_hybrid_noPM_diff6.txt',sep=',',comment='#',header=None)
SARSA_hybrid_noPM_diff4_bigenv= pd.read_csv('scores/no_pacman/SARSA/scores_SARSA_hybrid_noPM_diff4_bigenv.txt',sep=',',comment='#',header=None)

QL_noboost_noPM=                pd.read_csv('scores/no_pacman/Qlearning/scores_QL_noboost_noPM.txt',sep=',',comment='#',header=None)
QL_boost_noPM=                  pd.read_csv('scores/no_pacman/Qlearning/scores_QL_boost_noPM.txt',sep=',',comment='#',header=None)
QL_hybrid_noPM=                 pd.read_csv('scores/no_pacman/Qlearning/scores_QL_hybrid_noPM.txt',sep=',',comment='#',header=None)
QL_hybrid_noPM_bigenv=          pd.read_csv('scores/no_pacman/Qlearning/scores_QL_hybrid_noPM_bigenv.txt',sep=',',comment='#',header=None)
QL_hybrid_noPM_diff4=           pd.read_csv('scores/no_pacman/Qlearning/scores_QL_hybrid_noPM_diff4.txt',sep=',',comment='#',header=None)
QL_hybrid_noPM_diff6=           pd.read_csv('scores/no_pacman/Qlearning/scores_QL_hybrid_noPM_diff6.txt',sep=',',comment='#',header=None)
QL_hybrid_noPM_diff4_bigenv=    pd.read_csv('scores/no_pacman/Qlearning/scores_QL_hybrid_noPM_diff4_bigenv.txt',sep=',',comment='#',header=None)

ESARSA_noboost_noPM=            pd.read_csv('scores/no_pacman/ExpectedSARSA/scores_ESARSA_noboost_noPM.txt',sep=',',comment='#',header=None)
ESARSA_boost_noPM=              pd.read_csv('scores/no_pacman/ExpectedSARSA/scores_ESARSA_boost_noPM.txt',sep=',',comment='#',header=None)
ESARSA_hybrid_noPM=             pd.read_csv('scores/no_pacman/ExpectedSARSA/scores_ESARSA_hybrid_noPM.txt',sep=',',comment='#',header=None)
ESARSA_hybrid_noPM_bigenv=      pd.read_csv('scores/no_pacman/ExpectedSARSA/scores_ESARSA_hybrid_noPM_bigenv.txt',sep=',',comment='#',header=None)
ESARSA_hybrid_noPM_diff4=       pd.read_csv('scores/no_pacman/ExpectedSARSA/scores_ESARSA_hybrid_noPM_diff4.txt',sep=',',comment='#',header=None)
ESARSA_hybrid_noPM_diff6=       pd.read_csv('scores/no_pacman/ExpectedSARSA/scores_ESARSA_hybrid_noPM_diff6.txt',sep=',',comment='#',header=None)
ESARSA_hybrid_noPM_diff4_bigenv=pd.read_csv('scores/no_pacman/ExpectedSARSA/scores_ESARSA_hybrid_noPM_diff4_bigenv.txt',sep=',',comment='#',header=None)

# %%
# old states system, pacman
SARSA_noboost_PM=             pd.read_csv('old/scores/pacman/SARSA/scores_SARSA_noboost_PM.txt',sep=',',comment='#',header=None)
SARSA_boost_PM=               pd.read_csv('old/scores/pacman/SARSA/scores_SARSA_boost_PM.txt',sep=',',comment='#',header=None)
SARSA_hybrid_PM=              pd.read_csv('old/scores/pacman/SARSA/scores_SARSA_hybrid_PM.txt',sep=',',comment='#',header=None)
SARSA_hybrid_PM_bigenv=       pd.read_csv('old/scores/pacman/SARSA/scores_SARSA_hybrid_PM_bigenv.txt',sep=',',comment='#',header=None)
SARSA_hybrid_PM_diff4=        pd.read_csv('old/scores/pacman/SARSA/scores_SARSA_hybrid_PM_diff4.txt',sep=',',comment='#',header=None)
SARSA_hybrid_PM_diff6=        pd.read_csv('old/scores/pacman/SARSA/scores_SARSA_hybrid_PM_diff6.txt',sep=',',comment='#',header=None)
SARSA_hybrid6_PM=             pd.read_csv('old/scores/pacman/SARSA/scores_SARSA_hybrid6_PM.txt',sep=',',comment='#',header=None)
SARSA_hybrid_PM_diff4_bigenv= pd.read_csv('old/scores/pacman/SARSA/scores_SARSA_hybrid_PM_diff4_bigenv.txt',sep=',',comment='#',header=None)

QL_noboost_PM=                pd.read_csv('old/scores/pacman/Qlearning/scores_QL_noboost_PM.txt',sep=',',comment='#',header=None)
QL_boost_PM=                  pd.read_csv('old/scores/pacman/Qlearning/scores_QL_boost_PM.txt',sep=',',comment='#',header=None)
QL_hybrid_PM=                 pd.read_csv('old/scores/pacman/Qlearning/scores_QL_hybrid_PM.txt',sep=',',comment='#',header=None)
QL_hybrid_PM_bigenv=          pd.read_csv('old/scores/pacman/Qlearning/scores_QL_hybrid_PM_bigenv.txt',sep=',',comment='#',header=None)
QL_hybrid_PM_diff4=           pd.read_csv('old/scores/pacman/Qlearning/scores_QL_hybrid_PM_diff4.txt',sep=',',comment='#',header=None)
QL_hybrid_PM_diff6=           pd.read_csv('old/scores/pacman/Qlearning/scores_QL_hybrid_PM_diff6.txt',sep=',',comment='#',header=None)
QL_hybrid6_PM=                pd.read_csv('old/scores/pacman/Qlearning/scores_QL_hybrid6_PM.txt',sep=',',comment='#',header=None)
QL_hybrid_PM_diff4_bigenv=    pd.read_csv('old/scores/pacman/Qlearning/scores_QL_hybrid_PM_diff4_bigenv.txt',sep=',',comment='#',header=None)
 
ESARSA_noboost_PM=            pd.read_csv('old/scores/pacman/ExpectedSARSA/scores_ESARSA_noboost_PM.txt',sep=',',comment='#',header=None)
ESARSA_boost_PM=              pd.read_csv('old/scores/pacman/ExpectedSARSA/scores_ESARSA_boost_PM.txt',sep=',',comment='#',header=None)
ESARSA_hybrid_PM=             pd.read_csv('old/scores/pacman/ExpectedSARSA/scores_ESARSA_hybrid_PM.txt',sep=',',comment='#',header=None)
ESARSA_hybrid_PM_bigenv=      pd.read_csv('old/scores/pacman/ExpectedSARSA/scores_ESARSA_hybrid_PM_bigenv.txt',sep=',',comment='#',header=None)
ESARSA_hybrid_PM_diff4=       pd.read_csv('old/scores/pacman/ExpectedSARSA/scores_ESARSA_hybrid_PM_diff4.txt',sep=',',comment='#',header=None)
ESARSA_hybrid_PM_diff6=       pd.read_csv('old/scores/pacman/ExpectedSARSA/scores_ESARSA_hybrid_PM_diff6.txt',sep=',',comment='#',header=None)
ESARSA_hybrid6_PM=            pd.read_csv('old/scores/pacman/ExpectedSARSA/scores_ESARSA_hybrid6_PM.txt',sep=',',comment='#',header=None)
ESARSA_hybrid_PM_diff4_bigenv=pd.read_csv('old/scores/pacman/ExpectedSARSA/scores_ESARSA_hybrid_PM_diff4_bigenv.txt',sep=',',comment='#',header=None)

# %%
# new states system, pacman
test_SARSA_noboost_PM=             pd.read_csv('scores/pacman/SARSA/test_scores_SARSA_noboost_PM.txt',sep=',',comment='#',header=None)
test_SARSA_boost_PM=               pd.read_csv('scores/pacman/SARSA/test_scores_SARSA_boost_PM.txt',sep=',',comment='#',header=None)
test_SARSA_hybrid_PM=              pd.read_csv('scores/pacman/SARSA/test_scores_SARSA_hybrid_PM.txt',sep=',',comment='#',header=None)
test_SARSA_hybrid_PM_bigenv=       pd.read_csv('scores/pacman/SARSA/test_scores_SARSA_hybrid_PM_bigenv.txt',sep=',',comment='#',header=None)
test_SARSA_hybrid_PM_diff4=        pd.read_csv('scores/pacman/SARSA/test_scores_SARSA_hybrid_PM_diff4.txt',sep=',',comment='#',header=None)
test_SARSA_hybrid_PM_diff6=        pd.read_csv('scores/pacman/SARSA/test_scores_SARSA_hybrid_PM_diff6.txt',sep=',',comment='#',header=None)
test_SARSA_hybrid_PM_diff4_bigenv= pd.read_csv('scores/pacman/SARSA/test_scores_SARSA_hybrid_PM_diff4_bigenv.txt',sep=',',comment='#',header=None)

test_QL_noboost_PM=                pd.read_csv('scores/pacman/Qlearning/test_scores_Qlearning_noboost_PM.txt',sep=',',comment='#',header=None)
test_QL_boost_PM=                  pd.read_csv('scores/pacman/Qlearning/test_scores_Qlearning_boost_PM.txt',sep=',',comment='#',header=None)
test_QL_hybrid_PM=                 pd.read_csv('scores/pacman/Qlearning/test_scores_Qlearning_hybrid_PM.txt',sep=',',comment='#',header=None)
test_QL_hybrid_PM_bigenv=          pd.read_csv('scores/pacman/Qlearning/test_scores_Qlearning_hybrid_PM_bigenv.txt',sep=',',comment='#',header=None)
test_QL_hybrid_PM_diff4=           pd.read_csv('scores/pacman/Qlearning/test_scores_Qlearning_hybrid_PM_diff4.txt',sep=',',comment='#',header=None)
test_QL_hybrid_PM_diff6=           pd.read_csv('scores/pacman/Qlearning/test_scores_Qlearning_hybrid_PM_diff6.txt',sep=',',comment='#',header=None)
test_QL_hybrid_PM_diff4_bigenv=    pd.read_csv('scores/pacman/Qlearning/test_scores_Qlearning_hybrid_PM_diff4_bigenv.txt',sep=',',comment='#',header=None)

test_ESARSA_noboost_PM=            pd.read_csv('scores/pacman/ExpectedSARSA/test_scores_ESARSA_noboost_PM.txt',sep=',',comment='#',header=None)
test_ESARSA_boost_PM=              pd.read_csv('scores/pacman/ExpectedSARSA/test_scores_ESARSA_boost_PM.txt',sep=',',comment='#',header=None)
test_ESARSA_hybrid_PM=             pd.read_csv('scores/pacman/ExpectedSARSA/test_scores_ESARSA_hybrid_PM.txt',sep=',',comment='#',header=None)
test_ESARSA_hybrid_PM_bigenv=      pd.read_csv('scores/pacman/ExpectedSARSA/test_scores_ESARSA_hybrid_PM_bigenv.txt',sep=',',comment='#',header=None)
test_ESARSA_hybrid_PM_diff4=       pd.read_csv('scores/pacman/ExpectedSARSA/test_scores_ESARSA_hybrid_PM_diff4.txt',sep=',',comment='#',header=None)
test_ESARSA_hybrid_PM_diff6=       pd.read_csv('scores/pacman/ExpectedSARSA/test_scores_ESARSA_hybrid_PM_diff6.txt',sep=',',comment='#',header=None)
test_ESARSA_hybrid_PM_diff4_bigenv=pd.read_csv('scores/pacman/ExpectedSARSA/test_scores_ESARSA_hybrid_PM_diff4_bigenv.txt',sep=',',comment='#',header=None)

# %%
# new states system, no pacman
test_SARSA_noboost_noPM=             pd.read_csv('scores/no_pacman/SARSA/test_scores_SARSA_noboost_noPM.txt',sep=',',comment='#',header=None)
test_SARSA_boost_noPM=               pd.read_csv('scores/no_pacman/SARSA/test_scores_SARSA_boost_noPM.txt',sep=',',comment='#',header=None)
test_SARSA_hybrid_noPM=              pd.read_csv('scores/no_pacman/SARSA/test_scores_SARSA_hybrid_noPM.txt',sep=',',comment='#',header=None)
test_SARSA_hybrid_noPM_bigenv=       pd.read_csv('scores/no_pacman/SARSA/test_scores_SARSA_hybrid_noPM_bigenv.txt',sep=',',comment='#',header=None)
test_SARSA_hybrid_noPM_diff4=        pd.read_csv('scores/no_pacman/SARSA/test_scores_SARSA_hybrid_noPM_diff4.txt',sep=',',comment='#',header=None)
test_SARSA_hybrid_noPM_diff6=        pd.read_csv('scores/no_pacman/SARSA/test_scores_SARSA_hybrid_noPM_diff6.txt',sep=',',comment='#',header=None)
test_SARSA_hybrid_noPM_diff4_bigenv= pd.read_csv('scores/no_pacman/SARSA/test_scores_SARSA_hybrid_noPM_diff4_bigenv.txt',sep=',',comment='#',header=None)

test_QL_noboost_noPM=                pd.read_csv('scores/no_pacman/Qlearning/test_scores_Qlearning_noboost_noPM.txt',sep=',',comment='#',header=None)
test_QL_boost_noPM=                  pd.read_csv('scores/no_pacman/Qlearning/test_scores_Qlearning_boost_noPM.txt',sep=',',comment='#',header=None)
test_QL_hybrid_noPM=                 pd.read_csv('scores/no_pacman/Qlearning/test_scores_Qlearning_hybrid_noPM.txt',sep=',',comment='#',header=None)
test_QL_hybrid_noPM_bigenv=          pd.read_csv('scores/no_pacman/Qlearning/test_scores_Qlearning_hybrid_noPM_bigenv.txt',sep=',',comment='#',header=None)
test_QL_hybrid_noPM_diff4=           pd.read_csv('scores/no_pacman/Qlearning/test_scores_Qlearning_hybrid_noPM_diff4.txt',sep=',',comment='#',header=None)
test_QL_hybrid_noPM_diff6=           pd.read_csv('scores/no_pacman/Qlearning/test_scores_Qlearning_hybrid_noPM_diff6.txt',sep=',',comment='#',header=None)
test_QL_hybrid_noPM_diff4_bigenv=    pd.read_csv('scores/no_pacman/Qlearning/test_scores_Qlearning_hybrid_noPM_diff4_bigenv.txt',sep=',',comment='#',header=None)

test_ESARSA_noboost_noPM=            pd.read_csv('scores/no_pacman/ExpectedSARSA/test_scores_ESARSA_noboost_noPM.txt',sep=',',comment='#',header=None)
test_ESARSA_boost_noPM=              pd.read_csv('scores/no_pacman/ExpectedSARSA/test_scores_ESARSA_boost_noPM.txt',sep=',',comment='#',header=None)
test_ESARSA_hybrid_noPM=             pd.read_csv('scores/no_pacman/ExpectedSARSA/test_scores_ESARSA_hybrid_noPM.txt',sep=',',comment='#',header=None)
test_ESARSA_hybrid_noPM_bigenv=      pd.read_csv('scores/no_pacman/ExpectedSARSA/test_scores_ESARSA_hybrid_noPM_bigenv.txt',sep=',',comment='#',header=None)
test_ESARSA_hybrid_noPM_diff4=       pd.read_csv('scores/no_pacman/ExpectedSARSA/test_scores_ESARSA_hybrid_noPM_diff4.txt',sep=',',comment='#',header=None)
test_ESARSA_hybrid_noPM_diff6=       pd.read_csv('scores/no_pacman/ExpectedSARSA/test_scores_ESARSA_hybrid_noPM_diff6.txt',sep=',',comment='#',header=None)
test_ESARSA_hybrid_noPM_diff4_bigenv=pd.read_csv('scores/no_pacman/ExpectedSARSA/test_scores_ESARSA_hybrid_noPM_diff4_bigenv.txt',sep=',',comment='#',header=None)

# %%
# new test with zero starting policies, pacman
P_SARSA_noboost=                 pd.read_csv('new_zerostart/scores/pacman/SARSA/noboost.txt',sep=',',comment='#',header=None)
P_SARSA_boost4=                  pd.read_csv('new_zerostart/scores/pacman/SARSA/boost4.txt',sep=',',comment='#',header=None)
P_SARSA_smallcar=                pd.read_csv('new_zerostart/scores/pacman/SARSA/smallcar.txt',sep=',',comment='#',header=None)
P_SARSA_bigcar_boost5=           pd.read_csv('new_zerostart/scores/pacman/SARSA/bigcar_boost5.txt',sep=',',comment='#',header=None)
P_SARSA_bigcar_boost5_diff100=   pd.read_csv('new_zerostart/scores/pacman/SARSA/bigcar_boost5_diff100.txt',sep=',',comment='#',header=None)
P_SARSA_diff100=                 pd.read_csv('new_zerostart/scores/pacman/SARSA/diff100.txt',sep=',',comment='#',header=None)
P_SARSA_smallcar_boost3_diff100= pd.read_csv('new_zerostart/scores/pacman/SARSA/smallcar_boost3_diff100.txt',sep=',',comment='#',header=None)   
 
P_QL_noboost=                    pd.read_csv('new_zerostart/scores/pacman/Qlearning/noboost.txt',sep=',',comment='#',header=None)
P_QL_boost4=                     pd.read_csv('new_zerostart/scores/pacman/Qlearning/boost4.txt',sep=',',comment='#',header=None)
P_QL_smallcar=                   pd.read_csv('new_zerostart/scores/pacman/Qlearning/smallcar.txt',sep=',',comment='#',header=None)
P_QL_bigcar_boost5=              pd.read_csv('new_zerostart/scores/pacman/Qlearning/bigcar_boost5.txt',sep=',',comment='#',header=None)
P_QL_bigcar_boost5_diff100=      pd.read_csv('new_zerostart/scores/pacman/Qlearning/bigcar_boost5_diff100.txt',sep=',',comment='#',header=None)
P_QL_diff100=                    pd.read_csv('new_zerostart/scores/pacman/Qlearning/diff100.txt',sep=',',comment='#',header=None)
P_QL_smallcar_boost3_diff100=    pd.read_csv('new_zerostart/scores/pacman/Qlearning/smallcar_boost3_diff100.txt',sep=',',comment='#',header=None)
 
P_ESARSA_noboost=                pd.read_csv('new_zerostart/scores/pacman/ExpectedSARSA/noboost.txt',sep=',',comment='#',header=None)
P_ESARSA_boost4=                 pd.read_csv('new_zerostart/scores/pacman/ExpectedSARSA/boost4.txt',sep=',',comment='#',header=None)
P_ESARSA_smallcar=               pd.read_csv('new_zerostart/scores/pacman/ExpectedSARSA/smallcar.txt',sep=',',comment='#',header=None)
P_ESARSA_bigcar_boost5=          pd.read_csv('new_zerostart/scores/pacman/ExpectedSARSA/bigcar_boost5.txt',sep=',',comment='#',header=None)
P_ESARSA_bigcar_boost5_diff100=  pd.read_csv('new_zerostart/scores/pacman/ExpectedSARSA/bigcar_boost5_diff100.txt',sep=',',comment='#',header=None)
P_ESARSA_diff100=                pd.read_csv('new_zerostart/scores/pacman/ExpectedSARSA/diff100.txt',sep=',',comment='#',header=None)
P_ESARSA_smallcar_boost3_diff100=pd.read_csv('new_zerostart/scores/pacman/ExpectedSARSA/smallcar_boost3_diff100.txt',sep=',',comment='#',header=None)

# %%
# new test with zero starting policies, no pacman
NP_SARSA_noboost=                 pd.read_csv('new_zerostart/scores/no_pacman/SARSA/noboost.txt',sep=',',comment='#',header=None)
NP_SARSA_boost=                   pd.read_csv('new_zerostart/scores/no_pacman/SARSA/boost4.txt',sep=',',comment='#',header=None)
NP_SARSA_smallcar=                pd.read_csv('new_zerostart/scores/no_pacman/SARSA/smallcar.txt',sep=',',comment='#',header=None)
NP_SARSA_bigcar_boost5=           pd.read_csv('new_zerostart/scores/no_pacman/SARSA/bigcar_boost5.txt',sep=',',comment='#',header=None)
NP_SARSA_bigcar_boost5_diff100=   pd.read_csv('new_zerostart/scores/no_pacman/SARSA/bigcar_boost5_diff100.txt',sep=',',comment='#',header=None)
NP_SARSA_diff100=                 pd.read_csv('new_zerostart/scores/no_pacman/SARSA/diff100.txt',sep=',',comment='#',header=None)
NP_SARSA_smallcar_boost3_diff100= pd.read_csv('new_zerostart/scores/no_pacman/SARSA/smallcar_boost3_diff100.txt',sep=',',comment='#',header=None)
                                                                                                              
NP_QL_noboost=                    pd.read_csv('new_zerostart/scores/no_pacman/Qlearning/noboost.txt',sep=',',comment='#',header=None)
NP_QL_boost=                      pd.read_csv('new_zerostart/scores/no_pacman/Qlearning/boost4.txt',sep=',',comment='#',header=None)
NP_QL_smallcar=                   pd.read_csv('new_zerostart/scores/no_pacman/Qlearning/smallcar.txt',sep=',',comment='#',header=None)
NP_QL_bigcar_boost5=              pd.read_csv('new_zerostart/scores/no_pacman/Qlearning/bigcar_boost5.txt',sep=',',comment='#',header=None)
NP_QL_bigcar_boost5_diff100=      pd.read_csv('new_zerostart/scores/no_pacman/Qlearning/bigcar_boost5_diff100.txt',sep=',',comment='#',header=None)
NP_QL_diff100=                    pd.read_csv('new_zerostart/scores/no_pacman/Qlearning/diff100.txt',sep=',',comment='#',header=None)
NP_QL_smallcar_boost3_diff100=    pd.read_csv('new_zerostart/scores/no_pacman/Qlearning/smallcar_boost3_diff100.txt',sep=',',comment='#',header=None)
                                                                                                              
NP_ESARSA_noboost=                pd.read_csv('new_zerostart/scores/no_pacman/ExpectedSARSA/noboost.txt',sep=',',comment='#',header=None)
NP_ESARSA_boost=                  pd.read_csv('new_zerostart/scores/no_pacman/ExpectedSARSA/boost4.txt',sep=',',comment='#',header=None)
NP_ESARSA_smallcar=               pd.read_csv('new_zerostart/scores/no_pacman/ExpectedSARSA/smallcar.txt',sep=',',comment='#',header=None)
NP_ESARSA_bigcar_boost5=          pd.read_csv('new_zerostart/scores/no_pacman/ExpectedSARSA/bigcar_boost5.txt',sep=',',comment='#',header=None)
NP_ESARSA_bigcar_boost5_diff100=  pd.read_csv('new_zerostart/scores/no_pacman/ExpectedSARSA/bigcar_boost5_diff100.txt',sep=',',comment='#',header=None)
NP_ESARSA_diff100=                pd.read_csv('new_zerostart/scores/no_pacman/ExpectedSARSA/diff100.txt',sep=',',comment='#',header=None)
NP_ESARSA_smallcar_boost3_diff100=pd.read_csv('new_zerostart/scores/no_pacman/ExpectedSARSA/smallcar_boost3_diff100.txt',sep=',',comment='#',header=None)

# %%
# new test with zero starting policies and small number of iterations, no pacman
NP_SARSA_noboost_small=                 pd.read_csv('new_zero_small/scores/no_pacman/SARSA/noboost.txt',sep=',',comment='#',header=None)
NP_SARSA_boost_small=                   pd.read_csv('new_zero_small/scores/no_pacman/SARSA/boost4.txt',sep=',',comment='#',header=None)
NP_SARSA_smallcar_small=                pd.read_csv('new_zero_small/scores/no_pacman/SARSA/smallcar.txt',sep=',',comment='#',header=None)
NP_SARSA_bigcar_boost5_small=           pd.read_csv('new_zero_small/scores/no_pacman/SARSA/bigcar_boost5.txt',sep=',',comment='#',header=None)
NP_SARSA_bigcar_boost5_diff100_small=   pd.read_csv('new_zero_small/scores/no_pacman/SARSA/bigcar_boost5_diff100.txt',sep=',',comment='#',header=None)
NP_SARSA_diff100_small=                 pd.read_csv('new_zero_small/scores/no_pacman/SARSA/diff100.txt',sep=',',comment='#',header=None)
NP_SARSA_smallcar_boost3_diff100_small= pd.read_csv('new_zero_small/scores/no_pacman/SARSA/smallcar_boost3_diff100.txt',sep=',',comment='#',header=None)
 
NP_QL_noboost_small=                    pd.read_csv('new_zero_small/scores/no_pacman/Qlearning/noboost.txt',sep=',',comment='#',header=None)
NP_QL_boost_small=                      pd.read_csv('new_zero_small/scores/no_pacman/Qlearning/boost4.txt',sep=',',comment='#',header=None)
NP_QL_smallcar_small=                   pd.read_csv('new_zero_small/scores/no_pacman/Qlearning/smallcar.txt',sep=',',comment='#',header=None)
NP_QL_bigcar_boost5_small=              pd.read_csv('new_zero_small/scores/no_pacman/Qlearning/bigcar_boost5.txt',sep=',',comment='#',header=None)
NP_QL_bigcar_boost5_diff100_small=      pd.read_csv('new_zero_small/scores/no_pacman/Qlearning/bigcar_boost5_diff100.txt',sep=',',comment='#',header=None)
NP_QL_diff100_small=                    pd.read_csv('new_zero_small/scores/no_pacman/Qlearning/diff100.txt',sep=',',comment='#',header=None)
NP_QL_smallcar_boost3_diff100_small=    pd.read_csv('new_zero_small/scores/no_pacman/Qlearning/smallcar_boost3_diff100.txt',sep=',',comment='#',header=None)
 
NP_ESARSA_noboost_small=                pd.read_csv('new_zero_small/scores/no_pacman/ExpectedSARSA/noboost.txt',sep=',',comment='#',header=None)
NP_ESARSA_boost_small=                  pd.read_csv('new_zero_small/scores/no_pacman/ExpectedSARSA/boost4.txt',sep=',',comment='#',header=None)
NP_ESARSA_smallcar_small=               pd.read_csv('new_zero_small/scores/no_pacman/ExpectedSARSA/smallcar.txt',sep=',',comment='#',header=None)
NP_ESARSA_bigcar_boost5_small=          pd.read_csv('new_zero_small/scores/no_pacman/ExpectedSARSA/bigcar_boost5.txt',sep=',',comment='#',header=None)
NP_ESARSA_bigcar_boost5_diff100_small=  pd.read_csv('new_zero_small/scores/no_pacman/ExpectedSARSA/bigcar_boost5_diff100.txt',sep=',',comment='#',header=None)
NP_ESARSA_diff100_small=                pd.read_csv('new_zero_small/scores/no_pacman/ExpectedSARSA/diff100.txt',sep=',',comment='#',header=None)
NP_ESARSA_smallcar_boost3_diff100_small=pd.read_csv('new_zero_small/scores/no_pacman/ExpectedSARSA/smallcar_boost3_diff100.txt',sep=',',comment='#',header=None)

# %%
# new test with zero starting policies and small number of iterations, pacman
P_SARSA_noboost_small=                 pd.read_csv('new_zero_small/scores/pacman/SARSA/noboost.txt',sep=',',comment='#',header=None)
P_SARSA_boost_small=                   pd.read_csv('new_zero_small/scores/pacman/SARSA/boost4.txt',sep=',',comment='#',header=None)
P_SARSA_smallcar_small=                pd.read_csv('new_zero_small/scores/pacman/SARSA/smallcar.txt',sep=',',comment='#',header=None)
P_SARSA_bigcar_boost5_small=           pd.read_csv('new_zero_small/scores/pacman/SARSA/bigcar_boost5.txt',sep=',',comment='#',header=None)
P_SARSA_bigcar_boost5_diff100_small=   pd.read_csv('new_zero_small/scores/pacman/SARSA/bigcar_boost5_diff100.txt',sep=',',comment='#',header=None)
P_SARSA_diff100_small=                 pd.read_csv('new_zero_small/scores/pacman/SARSA/diff100.txt',sep=',',comment='#',header=None)
P_SARSA_smallcar_boost3_diff100_small= pd.read_csv('new_zero_small/scores/pacman/SARSA/smallcar_boost3_diff100.txt',sep=',',comment='#',header=None)

P_QL_noboost_small=                    pd.read_csv('new_zero_small/scores/pacman/Qlearning/noboost.txt',sep=',',comment='#',header=None)
P_QL_boost_small=                      pd.read_csv('new_zero_small/scores/pacman/Qlearning/boost4.txt',sep=',',comment='#',header=None)
P_QL_smallcar_small=                   pd.read_csv('new_zero_small/scores/pacman/Qlearning/smallcar.txt',sep=',',comment='#',header=None)
P_QL_bigcar_boost5_small=              pd.read_csv('new_zero_small/scores/pacman/Qlearning/bigcar_boost5.txt',sep=',',comment='#',header=None)
P_QL_bigcar_boost5_diff100_small=      pd.read_csv('new_zero_small/scores/pacman/Qlearning/bigcar_boost5_diff100.txt',sep=',',comment='#',header=None)
P_QL_diff100_small=                    pd.read_csv('new_zero_small/scores/pacman/Qlearning/diff100.txt',sep=',',comment='#',header=None)
P_QL_smallcar_boost3_diff100_small=    pd.read_csv('new_zero_small/scores/pacman/Qlearning/smallcar_boost3_diff100.txt',sep=',',comment='#',header=None)

P_ESARSA_noboost_small=                pd.read_csv('new_zero_small/scores/pacman/ExpectedSARSA/noboost.txt',sep=',',comment='#',header=None)
P_ESARSA_boost_small=                  pd.read_csv('new_zero_small/scores/pacman/ExpectedSARSA/boost4.txt',sep=',',comment='#',header=None)
P_ESARSA_smallcar_small=               pd.read_csv('new_zero_small/scores/pacman/ExpectedSARSA/smallcar.txt',sep=',',comment='#',header=None)
P_ESARSA_bigcar_boost5_small=          pd.read_csv('new_zero_small/scores/pacman/ExpectedSARSA/bigcar_boost5.txt',sep=',',comment='#',header=None)
P_ESARSA_bigcar_boost5_diff100_small=  pd.read_csv('new_zero_small/scores/pacman/ExpectedSARSA/bigcar_boost5_diff100.txt',sep=',',comment='#',header=None)
P_ESARSA_diff100_small=                pd.read_csv('new_zero_small/scores/pacman/ExpectedSARSA/diff100.txt',sep=',',comment='#',header=None)
P_ESARSA_smallcar_boost3_diff100_small=pd.read_csv('new_zero_small/scores/pacman/ExpectedSARSA/smallcar_boost3_diff100.txt',sep=',',comment='#',header=None)

NP_SARSA_gamma=pd.read_csv('scores/no_pacman/SARSA/test_gamma.txt',sep=',',comment='#',header=None)
NP_QL_gamma=pd.read_csv('scores/no_pacman/Qlearning/test_gamma.txt',sep=',',comment='#',header=None)
NP_ESARSA_gamma=pd.read_csv('scores/no_pacman/ExpectedSARSA/test_gamma.txt',sep=',',comment='#',header=None)

# %%
file='../Project_files/scores/no_pacman/ExpectedSARSA/smallcar_boost3_diff100.txt'
title='Exepected SARSA'
ymaxlim=1500
yminlim=0
xmaxlim=200
reps=10
scorescolor='darkkhaki'
meancolor='black'

data=pd.read_csv(file,sep=',',comment='#',header=None)
d1=data[0]
obsnum=len(d1)//reps
var=np.reshape(d1,(reps,obsnum))
means = np.mean(var, axis=0)
fig, ax = plt.subplots()

for i in range(10):
    ax.plot(var[i],scorescolor,alpha=0.4)
ax.plot(means, label='Mean value', color=meancolor, linewidth=1)

meansd1=[]
mediansd1=[]
data1p=[]
for i in range(0, len(means)): 
    new_data_point = means[i]
    data1p.append(new_data_point) 
    mean = np.mean(data1p)  
    median=np.median(data1p)
    meansd1.append(mean)
    mediansd1.append(median)
#ax.plot(meansd1, label='Mean', color='darkred', linewidth=3)
#ax.plot(mediansd1, label='Median', color='yellow', linewidth=2)


# Customize the plot with labels, legend, etc.
#ax.set_xlabel('Game number')
#ax.set_ylabel('Score')
ax.set_title(title)
#ax.legend(loc='upper left')
plt.xlim(0, xmaxlim)
plt.ylim(yminlim, ymaxlim)
# Show the plot
plt.show()

# %%
meansd1=[]
data1p=[]
meansd2=[]
data2p=[]
meansd3=[]
data3p=[]
mediansd1=[]
mediansd2=[]
mediansd3=[]

fig, ax = plt.subplots()

ax.set_xlabel("Game number")
ax.set_ylabel("Mean/median up to that point")

for i in range(0, len(d1)): 
    new_data_point = d1[i]
    data1p.append(new_data_point) 
    mean = np.mean(data1p)  
    #std=np.std(data1)
    med=np.median(data1p)
    meansd1.append(mean)  
    #stds.append(std)
    mediansd1.append(med)
for i in range(0, len(d2)): 
    new_data_point = d2[i]
    data2p.append(new_data_point) 
    mean = np.mean(data2p)  
    #std=np.std(data2)
    med=np.median(data2p)
    meansd2.append(mean)  
    #stds.append(std)
    mediansd2.append(med)

for i in range(0, len(d3)): 
    new_data_point = d3[i]
    data3p.append(new_data_point) 
    mean = np.mean(data3p)  
    #std=np.std(data3)
    med=np.median(data3p)
    meansd3.append(mean)  
    #stds.append(std)
    mediansd3.append(med)

# %%
plt.plot(x1,meansd1)
plt.plot(x2,meansd2)
plt.plot(x3,meansd3)
plt.ylim(0, 20)
plt.legend(['SARSA','Q-learning','Expected SARSA'],loc='upper left')
plt.show()

# %%
import seaborn as sns

sns.set()
N = len(data)-1

plt.plot(x, means, 'b-', label='means')
means=np.array(means)
stds=np.array(stds)

plt.fill_between(x, means - stds, means + stds, color='b', alpha=0.2)

plt.legend(title='title')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/davide/Desktop/Reinforcement_L/exam/Reinforcement-Learning-Project/images/plot_scores.ipynb Cell 13 line 6
#       <a href='vscode-notebook-cell:/home/davide/Desktop/Reinforcement_L/exam/Reinforcement-Learning-Project/images/plot_scores.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> sns.set()
#       <a href='vscode-notebook-cell:/home/davide/Desktop/Reinforcement_L/exam/Reinforcement-Learning-Project/images/plot_scores.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a> N = len(data)-1
# ----> <a href='vscode-notebook-cell:/home/davide/Desktop/Reinforcement_L/exam/Reinforcement-Learning-Project/images/plot_scores.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a> plt.plot(x, means, 'b-', label='means')
# ...
